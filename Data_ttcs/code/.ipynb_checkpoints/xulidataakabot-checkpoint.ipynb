# %%
import json
import csv
import pandas as pd
import numpy as np

# %%
datafpt1 = pd.read_excel('/Users/duymanh/Documents/Data_ttcs_akabot/data/datafpt1.xlsx', na_values = ':')
datafpt1
# Out:
#               iPhone 13 Pro Max 128GB  \
# 0         OPPO Reno7 Z 5G 8GB - 128GB
# 1   Samsung Galaxy S22 Ultra 5G 128GB
# 2                      iPhone 11 64GB
# 3                OPPO Reno7 8GB-128GB
# 4    Xiaomi 11 Lite 5G NE 8GB - 256GB
# ..                                ...
# 94                           Honor 8S
# 95                      Honor Play 3e
# 96                          Realme X2
# 97                      Realme X2 Pro
# 98                         Huawei Y6s
#
#        /dien-thoai/iphone-13-pro-max?dung-luong=128gb  30.490.000 ₫  \
# 0                            /dien-thoai/oppo-reno7-z           NaN
# 1   /dien-thoai/samsung-galaxy-s22-ultra?dung-luon...           NaN
# 2                          /dien-thoai/iphone-11-64gb  12.499.000 ₫
# 3               /dien-thoai/oppo-reno7?ho-tro-mang=4g   8.490.000 ₫
# 4   /dien-thoai/xiaomi-11-lite-5g-ne?dung-luong=8g...   9.490.000 ₫
# ..                                                ...           ...
# ...

# %%
df_datafpt1= pd.DataFrame(datafpt1,
                       columns=['name','url','price_selloff','price1','price2','hard_drive','size','memory','price'])
df_datafpt1.head()
